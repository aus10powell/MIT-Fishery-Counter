# %% [markdown]
# # Training Notebook

# %%
import glob
import os
import numpy as np
import time

# Vision
import cv2

## Utility
import xml.etree.ElementTree as ET
from tqdm import tqdm

import inference_utils

## Displaying in-cell
from IPython.display import Image
import matplotlib.pyplot as plt

## Analysis
from collections import Counter

# %load_ext lab_black

# %%
DOWNLOAD_DIR = os.path.join("/Users", "apowell", "Downloads")
assert os.path.isdir(DOWNLOAD_DIR)

DATA_DIR = os.path.join("..", "data", "Herring")

# Set path to training and test
TRAINING_DIR = os.path.join(DATA_DIR, "Training", "IRWA 2017 (Large+annotations)")
TESTING_DIR = os.path.join(DATA_DIR, "Testing")

os.path.isdir(DATA_DIR)  # assertion that we are pointed to correct folder
WEIGHTS_DIR = os.path.join("..", "weights_and_config")
HERRING_WEIGHTS = os.path.join(WEIGHTS_DIR, "Herring")

# %%
# Initialize model and set paths
model_config = os.path.join(HERRING_WEIGHTS, "herring.cfg")
model_weights = os.path.join(HERRING_WEIGHTS, "herring_final.weights")
# Initialize model
c = inference_utils.FishCounter(model_config=model_config, model_weights=model_weights)

# Test image
herring_image = "/Users/apowell/Downloads/BJ-Xdgso.jpeg"
c.load_image(image=herring_image)
boxes, counts, ind, class_ids = c.process_frame(time_inference=True)
print(boxes, counts, ind, class_ids)
# Sanity-check with annotated frame
c.get_annotated_frame()
# Out:
# Inference time on image: 0.53
# [] 0 () []

# %%
def get_dimensions_of_annotations(fpath):
    """Extracts dimensions of annotation boxes from xml file for image."""

    class_label = "herring"  # TODO: Will need to accomodate multiple classes

    tree = ET.parse(fpath)
    root = tree.getroot()

    xmins = []
    ymins = []
    xmaxs = []
    ymaxs = []
    for o in root.iter("object"):
        if o.find("name").text == class_label:
            xmins.append(eval(o[4][0].text))
            ymins.append(eval(o[4][1].text))
            xmaxs.append(eval(o[4][2].text))
            ymaxs.append(eval(o[4][3].text))
    return xmins, ymins, xmaxs, ymaxs


def bb_intersection_over_union(boxA, boxB):
    """Compute the intersection over union by taking the intersection area and dividing
    it by the sum of prediction + ground-truth areas - the interesection area"""
    # determine the (x, y)-coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])
    # compute the area of intersection rectangle
    interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
    print(interArea)
    # compute the area of both the prediction and ground-truth
    # rectangles
    boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
    print(boxAArea)
    boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
    print(boxBArea)

    return interArea / float(boxAArea + boxBArea - interArea)


def find_matching_path(annotations, images):
    """Finds the corresponding image or annotation path (i.e. given on path searches for the corresponding path)"""
    if type(annotations) == str:
        anchor, search = annotations, images
    elif type(images) == str:
        anchor, search = images, annotations
    else:
        print("Somethings wrong")
    return [p for p in search if anchor.split("/")[-1].split(".")[0] in p][
        0
    ]  # only need one

# %% [markdown]
# #### Set paths

# %%
folder = "Batch "
# Load images and annotations
# images_path1 = os.path.join(TRAINING_DIR, folder, "*.JPG")
# images_path2 = os.path.join(TRAINING_DIR, folder, "*.jpg")
images_path1 = os.path.join(DOWNLOAD_DIR, "HerringTrainingSet", "Images", "*.jpg")
images = glob.glob(images_path1)  # + glob.glob(images_path2)

# annotation_path = os.path.join(TRAINING_DIR, f"{folder} Annotations", "*.xml")
annotation_path = os.path.join(DOWNLOAD_DIR, "HerringTrainingSet", "Xml", "*.xml")
annotations = glob.glob(annotation_path)
print("{} images. Annotations: {}".format(len(images), len(annotations)))
# Out:
# 1111 images. Annotations: 1111

# %%
folder = "Batch 2"
# Load images and annotations
# images_path1 = os.path.join(TRAINING_DIR, folder, "*.JPG")
# images_path2 = os.path.join(TRAINING_DIR, folder, "*.jpg")
images_path1 = os.path.join(
    DOWNLOAD_DIR, "IRWA 2017 (Large+annotations)-2", "New Training Set", "*.png"
)
images = glob.glob(images_path1)  # + glob.glob(images_path2)

# annotation_path = os.path.join(TRAINING_DIR, f"{folder} Annotations", "*.xml")
annotation_path = os.path.join(
    DOWNLOAD_DIR,
    "IRWA 2017 (Large+annotations)-2",
    "New Training Set",
    "annotations",
    "*.xml",
)
print(annotation_path)
annotations = glob.glob(annotation_path)
print("{} images. Annotations: {}".format(len(images), len(annotations)))
# Out:
# /Users/apowell/Downloads/IRWA 2017 (Large+annotations)-2/New Training Set/annotations/*.xml
# 94 images. Annotations: 94

# %%
os.listdir(os.path.join(DATA_DIR, "Training", "IRWA 2017 (Large+annotations)"))
# Out:
# ['IRWA Small Jpgs', '.DS_Store', 'Images', 'New Training Set', 'Annotations']

# %%
images = glob.glob(
    os.path.join(
        DATA_DIR, "Training", "IRWA 2017 (Large+annotations)", "Images", "*.jpg"
    )
)
annotations = glob.glob(
    os.path.join(
        DATA_DIR, "Training", "IRWA 2017 (Large+annotations)", "Annotations", "*.xml"
    )
)

print("{} images. Annotations: {}".format(len(images), len(annotations)))
# Out:
# 234 images. Annotations: 198

# %%
# Example: Finding matching paths
test = images[0]
print("test:", test)
test_match = find_matching_path(images=test, annotations=annotations)
print("test match:", test_match)
# Out:
# test: /Users/apowell/Downloads/HerringTestSet/Images/1_2016-04-21_21-50-1808716.jpg
# test match: /Users/apowell/Downloads/HerringTestSet/Xml/1_2016-04-21_21-50-1808716.xml

# %% [markdown]
# ## Scoring annotations against inference
# **Requirements:** 2 folders: 1 with annotations (e.g. XML), 1 with images
# * **Steps:**
#   * 1) Run loop on images extracting predicted boxes from each image
#   * 2) Scan filenames until box is properly extracted
#   * 3) **Scoring Method:**
#     * For each annotation find closest/any overlapping boxes (scoring the greater of number of either the annotated or predicted set distinctly)
#     * Return average IOU for image
#     * Return total number of correctly detected fish

# %%
def display_image_comparison(img_path=None, annotated_box=None, predicted_box=None):
    import matplotlib.pyplot as plt
    import cv2

    """Display an image with optional annotated class and predicted class within notebook for comparison.
    image_path: image path to location in memory
    annotated_box: corners in format xmin,xmax,ymin,ymax
    """

    label = "herring"

    img_name = img_path.split("/")[-1].split(".")[0]
    frame = cv2.imread(img_path)

    # Annotated
    cv2.rectangle(
        frame,
        (annotated_box[0], annotated_box[1]),
        (annotated_box[2], annotated_box[3]),
        (178, 255, 255),
        2,
    )

    # Annotated
    # Predicted
    if predicted_box is not None:
        cv2.rectangle(
            frame,
            (predicted_box[0], predicted_box[1]),
            (predicted_box[2], predicted_box[3]),
            (144, 238, 144),
            3,
        )
    cv2.putText(
        frame,
        "Annotated " + label,
        (annotated_box[0], annotated_box[1]),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.55,
        (178, 255, 255),
        1,
    )
    cv2.putText(
        frame,
        "Predicted " + label,
        (annotated_box[1], annotated_box[2]),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.55,
        (144, 238, 144),
        1,
    )
    plt.imshow(frame)
    plt.title(img_name)
    plt.show()


## Example files
# 1 count: ../data/Herring/Training/IRWA 2017 (Large+annotations)/Batch 1/2_2017-04-14_11-42-13_large.jpg
# herring_image = "../data/Herring/Training/IRWA 2017 (Large+annotations)/Batch 1/2_2017-04-14_11-42-13_large.jpg"
# boxes = [[56, 134, 97, 48]]

# # 1 count: ../data/Herring/Training/IRWA 2017 (Large+annotations)/Batch 1/2_2017-04-14_10-51-06_large.jpg
# herring_image = "../data/Herring/Training/IRWA 2017 (Large+annotations)/Batch 1/2_2017-04-14_10-51-06_large.jpg"
# boxes = [[6, 110, 107, 56]]

# print(herring_image, boxes)
# # Get index of annotation path files that contains the path to annotated file matching the non-annoated file
# idx = [
#     i
#     for i in range(len(annotations))
#     if herring_image.split("/")[-1].split(".")[0] in annotations[i]
# ][
#     0
# ]  # Get the first element (multiple matches do not matter)


# xmins, xmaxs, ymins, ymaxs = get_dimensions_of_annotations(fpath=annotations[idx])

# # Predicted
# left, top, width, height = boxes[0][0], boxes[0][1], boxes[0][2], boxes[0][3]
# xmin, ymin, xmax, ymax = left, top, left + width, top + height
# predicted_box = xmin, ymin, xmax, ymax
# # Annotated
# annotated_box = xmins[0], xmaxs[0], ymins[0], ymaxs[0]
# print("IOU Score:", bb_intersection_over_union(boxA=predicted_box, boxB=annotated_box))

# display_image_comparison(
#     img_path=herring_image, annotated_box=annotated_box, predicted_box=predicted_box
# )  # predicted_box

# %%
# Find the annotation file
annotation_file = find_matching_path(
    images=herring_image.split("/")[-1].split(".")[0], annotations=annotations
)
get_dimensions_of_annotations(fpath=a)
# xmins, xmaxs, ymins, ymaxs = get_dimensions_of_annotations(fpath=a)
# annotated_box = xmins[0], xmaxs[0], ymins[0], ymaxs[0]

# display_image_comparison(
#     img_path=herring_image, annotated_box=annotated_box, predicted_box=None
# )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [11], line 2
#       1 # Find the annotation file
# ----> 2 annotation_file = find_matching_path(
#       3     images=herring_image.split("/")[-1].split(".")[0], annotations=annotations
#       4 )
#       5 get_dimensions_of_annotations(fpath=a)
#
# Cell In [4], line 51, in find_matching_path(annotations, images)
#      49 else:
#      50     print("Somethings wrong")
# ---> 51 return [p for p in search if anchor.split("/")[-1].split(".")[0] in p][
#      52     0
#      53 ]
#
# IndexError: list index out of range

# %% [markdown]
# ## Evaluation

# %%
iou_scores = []
annotated_counts = []
predicted_counts = []
# Loop through annotated files
i, n = 0, len(annotations)

for a in annotations:
    print(f"{i} of {n}")
    i += 1
    name = a.split("/")[-1].split(".")[0]

    # Loop through image files (non-annotated) to make a prediction on
    for herring_image in images:

        if name not in herring_image:
            continue
        else:
            print("a--->", a, "\n", "herring_image--->", herring_image)

        c.load_image(image=herring_image)
        boxes, counts, ind, class_ids = c.process_frame(time_inference=True)

        # Get score
        xmins, xmaxs, ymins, ymaxs = get_dimensions_of_annotations(fpath=a)
        # Predicted
        if len(boxes) == 0:  # If nothing was predicted
            boxes = [[0, 0, 0, 0]]
        left, top, width, height = boxes[0][0], boxes[0][1], boxes[0][2], boxes[0][3]
        xmin, ymin, xmax, ymax = left, top, left + width, top + height
        predicted_box = xmin, ymin, xmax, ymax
        # Annotated
        if len(xmins) == 0:  # If nothing was annotated
            annotated_box = [0, 0, 0, 0]
            annotated_count = 0
        else:
            annotated_box = xmins[0], xmaxs[0], ymins[0], ymaxs[0]
            annotated_count = len(xmins)

        annotated_counts.append(annotated_count)
        predicted_counts.append(counts)
        iou_score = bb_intersection_over_union(boxA=predicted_box, boxB=annotated_box)
        iou_scores.append(iou_score)
        print("annotated_count", annotated_count)
        print("counts", counts)
        print("IOU Score:", iou_score)
        print()
    cv2.destroyAllWindows()
# Out:
# 0 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_15-30-08_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_15-30-08_large.jpg
# Inference time on image: 0.52
# 0
# 1
# 4640
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 1 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_11-42-13_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_11-42-13_large.jpg
# [0.32865852 0.6587873  0.30487534 0.20038645 0.8971311  0.8971311 ]
# Inference time on image: 0.61
# 3626
# 4802
# 3700
# annotated_count 1
# counts 1
# IOU Score: 0.743642329778507
#
# 2 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_10-51-06_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_10-51-06_large.jpg
# [0.1878179  0.57741845 0.33692092 0.23485109 0.91039896 0.91039896]
# Inference time on image: 0.53
# 5184
# 6156
# 5635
# annotated_count 1
# counts 1
# IOU Score: 0.78462237021341
#
# 3 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_15-18-09_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_15-18-09_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 6450
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 4 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_17-45-21_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_17-45-21_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 4641
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 5 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-22_13-13-00_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-22_13-13-00_large.jpg
# [0.29713368 0.4303046  0.34848416 0.19673131 0.876205   0.876205  ]
# Inference time on image: 0.56
# 4816
# 5376
# 4945
# annotated_count 1
# counts 1
# IOU Score: 0.8748410535876476
#
# 6 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_18-48-07_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_18-48-07_large.jpg
# [0.4828927 0.7970744 0.946511  0.3247077 0.80535   0.80535  ]
# Inference time on image: 0.54
# 0
# 23634
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 7 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-21_13-30-27_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-21_13-30-27_large.jpg
# [0.66843325 0.9016247  0.29954547 0.16566673 0.81319207 0.81319207]
# Inference time on image: 0.44
# 0
# 3840
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 8 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_11-30-46_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_11-30-46_large.jpg
# [0.3371907  0.57600754 0.24674599 0.17456466 0.8827041  0.8827041 ]
# Inference time on image: 0.59
# 2686
# 3318
# 3638
# annotated_count 1
# counts 1
# IOU Score: 0.62903981264637
#
# 9 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_15-47-53_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_15-47-53_large.jpg
# [0.57825655 0.73355365 0.7512411  0.4102464  0.61980534 0.61980534]
# Inference time on image: 0.52
# 6486
# 23859
# 6486
# annotated_count 1
# counts 1
# IOU Score: 0.2718471017226204
#
# 10 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-21_12-05-16_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-21_12-05-16_large.jpg
# [0.42918253 0.8778163  0.4215633  0.21669991 0.80428946 0.80428946]
# Inference time on image: 0.51
# 0
# 7155
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 11 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_13-17-01_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_13-17-01_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 5676
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 12 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-20_11-51-11_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-20_11-51-11_large.jpg
# [0.35881758 0.5000153  0.28290156 0.19833694 0.8293116  0.8293116 ]
# Inference time on image: 0.52
# 3640
# 4368
# 4080
# annotated_count 1
# counts 1
# IOU Score: 0.757071547420965
#
# 13 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_14-58-23_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_14-58-23_large.jpg
# Inference time on image: 0.40
# 0
# 1
# 9860
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 14 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_17-02-53_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_17-02-53_large.jpg
# Inference time on image: 0.41
# 0
# 1
# 4578
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 15 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_14-20-43_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_14-20-43_large.jpg
# [0.6287595  0.4867531  0.2961956  0.23316143 0.8721613  0.8721613 ]
# [0.5049256  0.56728476 0.33149788 0.21147095 0.8184114  0.8184114 ]
# Inference time on image: 0.59
# 2016
# 5320
# 5824
# annotated_count 2
# counts 2
# IOU Score: 0.22085889570552147
#
# 16 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_09-37-36_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_09-37-36_large.jpg
# [0.1933808  0.6036927  0.3585202  0.21323378 0.9057147  0.9057147 ]
# Inference time on image: 0.75
# 4600
# 5980
# 4920
# annotated_count 1
# counts 1
# IOU Score: 0.7301587301587301
#
# 17 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_17-52-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_17-52-12_large.jpg
# Inference time on image: 0.69
# 0
# 1
# 3060
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 18 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_10-58-13_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_10-58-13_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 6696
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 19 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-20_13-27-50_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-20_13-27-50_large.jpg
# Inference time on image: 0.57
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 20 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_07-04-40_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_07-04-40_large.jpg
# [0.32632956 0.6076094  0.3628804  0.18579188 0.79954046 0.79954046]
# [0.48826283 0.7977461  0.98658025 0.36155275 0.6577914  0.6577914 ]
# Inference time on image: 0.54
# 5031
# 5265
# 5633
# annotated_count 1
# counts 2
# IOU Score: 0.8575080961309016
#
# 21 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_11-48-40_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_11-48-40_large.jpg
# [0.44843775 0.8033225  0.890186   0.36896256 0.6279195  0.6279195 ]
# Inference time on image: 0.49
# 3780
# 25365
# 3780
# annotated_count 1
# counts 1
# IOU Score: 0.14902424600827913
#
# 22 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_18-03-22_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_18-03-22_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 4428
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 23 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_08-30-20_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_08-30-20_large.jpg
# [0.39980796 0.6668025  0.4001064  0.20235722 0.6517962  0.6517962 ]
# Inference time on image: 0.44
# 5207
# 6321
# 5412
# annotated_count 1
# counts 1
# IOU Score: 0.7978853815507202
#
# 24 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_13-24-02_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_13-24-02_large.jpg
# Inference time on image: 0.54
# 0
# 1
# 3706
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 25 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_18-13-47_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_18-13-47_large.jpg
# [0.50535256 0.8010119  0.8877423  0.33250844 0.67180705 0.67180705]
# Inference time on image: 0.46
# 0
# 22800
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 26 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_11-30-21_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_11-30-21_large.jpg
# [0.44466287 0.74688625 0.91350245 0.37152925 0.6694097  0.6694097 ]
# Inference time on image: 0.50
# 3300
# 26370
# 3300
# annotated_count 1
# counts 1
# IOU Score: 0.12514220705346984
#
# 27 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_10-34-00_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_10-34-00_large.jpg
# Inference time on image: 0.52
# 0
# 1
# 4329
# annotated_count 2
# counts 0
# IOU Score: 0.0
#
# 28 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_11-31-46_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_11-31-46_large.jpg
# Inference time on image: 0.38
# 0
# 1
# 3185
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 29 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_10-05-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_10-05-12_large.jpg
# Inference time on image: 0.47
# 0
# 1
# 3800
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 30 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_13-23-24_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_13-23-24_large.jpg
# [0.10325044 0.47086117 0.20834401 0.2346921  0.89034235 0.89034235]
# Inference time on image: 0.58
# 3102
# 3819
# 3196
# annotated_count 1
# counts 1
# IOU Score: 0.7927421415793509
#
# 31 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-20_11-15-56_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-20_11-15-56_large.jpg
# [0.32895228 0.56022716 0.18074137 0.38473266 0.6499693  0.6499693 ]
# Inference time on image: 0.44
# 4408
# 5394
# 5390
# annotated_count 1
# counts 1
# IOU Score: 0.6913425345043914
#
# 32 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_10-12-53_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_10-12-53_large.jpg
# Inference time on image: 0.43
# 0
# 1
# 7752
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 33 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_18-00-55_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_18-00-55_large.jpg
# [0.39980808 0.58442855 0.40452942 0.2640555  0.85262734 0.85262734]
# Inference time on image: 0.50
# 6370
# 8320
# 7840
# annotated_count 2
# counts 1
# IOU Score: 0.6506639427987743
#
# 34 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_15-36-41_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_15-36-41_large.jpg
# [0.4997512  0.7440806  1.0479498  0.32823727 0.61661094 0.61661094]
# Inference time on image: 0.50
# 3930
# 26544
# 3930
# annotated_count 1
# counts 1
# IOU Score: 0.14805605786618445
#
# 35 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_12-56-33_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_12-56-33_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 780
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 36 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_08-11-26_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_08-11-26_large.jpg
# [0.49784294 0.74601656 0.887901   0.38299322 0.7562072  0.7562072 ]
# Inference time on image: 0.62
# 7952
# 26220
# 7952
# annotated_count 1
# counts 1
# IOU Score: 0.30327993897787947
#
# 37 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_18-45-59_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_18-45-59_large.jpg
# Inference time on image: 0.40
# 0
# 1
# 6210
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 38 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-22_14-18-43_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-22_14-18-43_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 4680
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 39 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_10-07-30_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_10-07-30_large.jpg
# [0.48652473 0.79731834 0.90107286 0.34560388 0.64115137 0.64115137]
# Inference time on image: 0.46
# 4095
# 23987
# 4410
# annotated_count 1
# counts 1
# IOU Score: 0.16850464982305982
#
# 40 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_17-55-45_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_17-55-45_large.jpg
# [0.51452804 0.7466829  0.8172385  0.32273358 0.7761617  0.7761617 ]
# Inference time on image: 0.57
# 4797
# 20436
# 4797
# annotated_count 1
# counts 1
# IOU Score: 0.23473282442748092
#
# 41 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_15-07-28_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_15-07-28_large.jpg
# Inference time on image: 0.41
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 42 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_10-59-23_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_10-59-23_large.jpg
# Inference time on image: 0.41
# 0
# 1
# 7242
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 43 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_18-12-29_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_18-12-29_large.jpg
# [0.2509232  0.59231675 0.3456033  0.21226658 0.8715057  0.8715057 ]
# Inference time on image: 0.53
# 3325
# 5661
# 4018
# annotated_count 3
# counts 1
# IOU Score: 0.5232924142272585
#
# 44 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-24_17-00-29_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-24_17-00-29_large.jpg
# Inference time on image: 0.60
# 0
# 1
# 4042
# annotated_count 3
# counts 0
# IOU Score: 0.0
#
# 45 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_19-21-28_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_19-21-28_large.jpg
# Inference time on image: 0.63
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 46 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_16-41-34_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_16-41-34_large.jpg
# [0.20188986 0.7283141  0.2790154  0.2711584  0.73802555 0.73802555]
# Inference time on image: 0.56
# 4042
# 5940
# 4230
# annotated_count 1
# counts 1
# IOU Score: 0.6595953002610966
#
# 47 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_13-10-00_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_13-10-00_large.jpg
# [0.26516992 0.65304846 0.38072208 0.26961    0.87488085 0.87488085]
# Inference time on image: 0.60
# 4880
# 7930
# 5200
# annotated_count 1
# counts 1
# IOU Score: 0.5915151515151515
#
# 48 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-05-27_07-46-01_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-05-27_07-46-01_large.jpg
# Inference time on image: 0.41
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 49 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_10-45-20_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_10-45-20_large.jpg
# [0.18187168 0.7497212  0.34102747 0.26309097 0.6605149  0.6605149 ]
# Inference time on image: 0.61
# 0
# 7040
# 4284
# annotated_count 2
# counts 1
# IOU Score: 0.0
#
# 50 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_16-39-05_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_16-39-05_large.jpg
# Inference time on image: 0.59
# 0
# 1
# 3515
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 51 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_12-58-11_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_12-58-11_large.jpg
# Inference time on image: 0.77
# 0
# 1
# 2262
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 52 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_11-00-06_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_11-00-06_large.jpg
# [0.19787447 0.6195322  0.3546861  0.2513554  0.93743896 0.93743896]
# Inference time on image: 0.45
# 5264
# 6954
# 5452
# annotated_count 1
# counts 1
# IOU Score: 0.7370484458134976
#
# 53 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_12-01-54_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_12-01-54_large.jpg
# [0.48439676 0.8124545  0.9397159  0.3952349  0.67034227 0.67034227]
# Inference time on image: 0.45
# 3922
# 28595
# 3922
# annotated_count 1
# counts 1
# IOU Score: 0.13715684560237804
#
# 54 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_08-37-14_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_08-37-14_large.jpg
# Inference time on image: 0.48
# 0
# 1
# 4356
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 55 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_14-38-01_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_14-38-01_large.jpg
# [0.5045627  0.7936727  0.99188656 0.4152824  0.7024884  0.7024884 ]
# Inference time on image: 0.51
# 0
# 31800
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 56 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-23_11-14-13_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-23_11-14-13_large.jpg
# [0.2257541  0.5705419  0.3429658  0.22765245 0.9260686  0.9260686 ]
# Inference time on image: 0.73
# 5060
# 6050
# 5612
# annotated_count 1
# counts 1
# IOU Score: 0.7664344138139958
#
# 57 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_08-26-44_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_08-26-44_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 5764
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 58 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_16-48-26_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_16-48-26_large.jpg
# Inference time on image: 0.41
# 0
# 1
# 6700
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 59 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-05-27_06-46-06_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-05-27_06-46-06_large.jpg
# Inference time on image: 0.40
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 60 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_11-40-43_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_11-40-43_large.jpg
# [0.1446102  0.5785318  0.25680262 0.1900884  0.88426006 0.88426006]
# Inference time on image: 0.59
# 2739
# 3818
# 2937
# annotated_count 1
# counts 1
# IOU Score: 0.6820219123505976
#
# 61 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_07-45-44_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_07-45-44_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 5124
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 62 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_12-12-52_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_12-12-52_large.jpg
# [0.49675485 0.82422775 0.9177973  0.3202265  0.684265   0.684265  ]
# [0.14994694 0.88426995 0.2859643  0.1912939  0.87781197 0.87781197]
# Inference time on image: 0.54
# 0
# 22638
# 1
# annotated_count 0
# counts 2
# IOU Score: 0.0
#
# 63 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_17-40-07_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_17-40-07_large.jpg
# [0.13900734 0.8961948  0.29694822 0.15664662 0.8603427  0.8603427 ]
# Inference time on image: 0.46
# 0
# 3648
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 64 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_06-26-13_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_06-26-13_large.jpg
# Inference time on image: 0.44
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 65 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_19-07-49_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_19-07-49_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 5670
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 66 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_15-59-19_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_15-59-19_large.jpg
# Inference time on image: 0.42
# 0
# 1
# 12474
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 67 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_18-23-07_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_18-23-07_large.jpg
# [0.5024712  0.7436588  0.90481675 0.42465416 0.64851147 0.64851147]
# Inference time on image: 0.50
# 6578
# 29580
# 6578
# annotated_count 1
# counts 1
# IOU Score: 0.22237998647734955
#
# 68 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_12-19-49_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_12-19-49_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 2961
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 69 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-05-27_09-12-00_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-05-27_09-12-00_large.jpg
# [0.43161404 0.7901087  0.7192208  0.25475886 0.6601688  0.6601688 ]
# Inference time on image: 0.44
# 0
# 14322
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 70 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_18-41-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_18-41-12_large.jpg
# Inference time on image: 0.43
# 0
# 1
# 6120
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 71 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_10-27-13_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_10-27-13_large.jpg
# Inference time on image: 0.44
# 0
# 1
# 5456
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 72 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-20_13-37-40_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-20_13-37-40_large.jpg
# [0.3709912  0.743366   0.3485891  0.26847517 0.6314148  0.6314148 ]
# Inference time on image: 0.55
# 0
# 7280
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 73 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-21_16-21-20_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-21_16-21-20_large.jpg
# [0.3307091  0.8854965  0.4245992  0.20408742 0.86624086 0.86624086]
# Inference time on image: 0.51
# 0
# 6664
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 74 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_17-27-26_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_17-27-26_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 8321
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 75 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_19-00-29_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_19-00-29_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 3705
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 76 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_11-13-19_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_11-13-19_large.jpg
# [0.3483844  0.86835754 0.4026278  0.23151016 0.86083895 0.86083895]
# Inference time on image: 0.51
# 0
# 7224
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 77 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_16-49-57_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_16-49-57_large.jpg
# Inference time on image: 0.41
# 0
# 1
# 6255
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 78 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_12-36-23_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_12-36-23_large.jpg
# [0.58599496 0.86406964 0.71877074 0.2567398  0.8991638  0.8991638 ]
# Inference time on image: 0.54
# 10032
# 14322
# 10450
# annotated_count 1
# counts 1
# IOU Score: 0.6805970149253732
#
# 79 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_17-35-04_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_17-35-04_large.jpg
# Inference time on image: 0.39
# 0
# 1
# 2340
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 80 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_18-34-16_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_18-34-16_large.jpg
# Inference time on image: 0.40
# 0
# 1
# 5206
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 81 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_09-59-50_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_09-59-50_large.jpg
# [0.2807464  0.6554223  0.38148206 0.28194886 0.806038   0.806038  ]
# Inference time on image: 0.45
# 6765
# 8364
# 7620
# annotated_count 1
# counts 1
# IOU Score: 0.7338106085258704
#
# 82 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_07-40-58_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_07-40-58_large.jpg
# [0.4974117  0.79790884 0.879091   0.33203807 0.65241396 0.65241396]
# [0.16145548 0.8617988  0.30036193 0.22742964 0.8904403  0.8904403 ]
# Inference time on image: 0.56
# 0
# 22560
# 1
# annotated_count 0
# counts 2
# IOU Score: 0.0
#
# 83 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_16-39-36_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_16-39-36_large.jpg
# Inference time on image: 0.43
# 0
# 1
# 3944
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 84 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_18-48-50_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_18-48-50_large.jpg
# Inference time on image: 0.42
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 85 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-05-29_08-33-54_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-05-29_08-33-54_large.jpg
# [0.4986126  0.7342231  0.90800625 0.33614066 0.69583327 0.69583327]
# Inference time on image: 0.48
# 1926
# 23571
# 3531
# annotated_count 1
# counts 1
# IOU Score: 0.07650142993326978
#
# 86 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_10-35-32_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_10-35-32_large.jpg
# [0.5014909  0.7359495  0.79462826 0.37534332 0.83081746 0.83081746]
# Inference time on image: 0.58
# 5265
# 23205
# 5265
# annotated_count 2
# counts 1
# IOU Score: 0.226890756302521
#
# 87 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-24_06-51-34_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-24_06-51-34_large.jpg
# Inference time on image: 0.42
# 0
# 1
# 5070
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 88 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_11-14-27_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_11-14-27_large.jpg
# [0.26024434 0.6034432  0.27605745 0.19299914 0.89134187 0.89134187]
# Inference time on image: 0.45
# 3293
# 4183
# 3515
# annotated_count 1
# counts 1
# IOU Score: 0.7475595913734393
#
# 89 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_05-58-46_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_05-58-46_large.jpg
# Inference time on image: 0.43
# 0
# 1
# 5676
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 90 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_16-29-28_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_16-29-28_large.jpg
# Inference time on image: 0.42
# 0
# 1
# 9984
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 91 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_18-16-04_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_18-16-04_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 3885
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 92 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_15-21-48_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_15-21-48_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 3597
# annotated_count 2
# counts 0
# IOU Score: 0.0
#
# 93 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_16-22-07_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_16-22-07_large.jpg
# [0.13703376 0.75780666 0.25224167 0.24698156 0.8778396  0.8778396 ]
# Inference time on image: 0.60
# 3969
# 4860
# 4459
# annotated_count 1
# counts 1
# IOU Score: 0.7418691588785047
#
# 94 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_09-11-48_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_09-11-48_large.jpg
# [0.4465738  0.7551132  0.94226956 0.31923264 0.74444324 0.74444324]
# Inference time on image: 0.47
# 0
# 23254
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 95 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_16-52-03_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_16-52-03_large.jpg
# [0.50850713 0.7500667  0.8728911  0.351591   0.6690675  0.6690675 ]
# Inference time on image: 0.56
# 0
# 23800
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 96 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-24_15-21-23_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-24_15-21-23_large.jpg
# Inference time on image: 0.48
# 0
# 1
# 4960
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 97 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_16-04-05_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_16-04-05_large.jpg
# Inference time on image: 0.48
# 0
# 1
# 4935
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 98 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_18-37-43_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_18-37-43_large.jpg
# [0.48599428 0.74337363 0.8585935  0.34199765 0.7559874  0.7559874 ]
# Inference time on image: 0.51
# 4290
# 22825
# 5060
# annotated_count 1
# counts 1
# IOU Score: 0.18181818181818182
#
# 99 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_07-55-00_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_07-55-00_large.jpg
# [0.35002607 0.6092831  0.31425047 0.18173483 0.6513692  0.6513692 ]
# Inference time on image: 0.66
# 3800
# 4444
# 4180
# annotated_count 2
# counts 1
# IOU Score: 0.7877280265339967
#
# 100 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_09-57-34_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_09-57-34_large.jpg
# [0.8248028  0.8242079  0.32263744 0.2906632  0.6923796  0.6923796 ]
# Inference time on image: 0.49
# 0
# 7280
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 101 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_06-22-57_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_06-22-57_large.jpg
# [0.50700295 0.8080903  1.03255    0.3295049  0.632721   0.632721  ]
# Inference time on image: 0.57
# 6336
# 26480
# 6600
# annotated_count 1
# counts 1
# IOU Score: 0.23691295243793
#
# 102 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_10-00-45_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_10-00-45_large.jpg
# [0.18557285 0.6092228  0.31427696 0.2248849  0.87140936 0.87140936]
# [0.41280258 0.7944606  0.94931513 0.36988056 0.77928936 0.77928936]
# Inference time on image: 0.52
# 3535
# 5454
# 3675
# annotated_count 2
# counts 2
# IOU Score: 0.6319270647121916
#
# 103 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_13-39-06_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_13-39-06_large.jpg
# [0.32852343 0.43255103 0.40998137 0.20241305 0.8924672  0.8924672 ]
# Inference time on image: 0.63
# 5940
# 6468
# 7350
# annotated_count 1
# counts 1
# IOU Score: 0.753998476770754
#
# 104 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-21_15-59-54_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-21_15-59-54_large.jpg
# Inference time on image: 0.46
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 105 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_18-03-32_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_18-03-32_large.jpg
# [0.25478065 0.5641402  0.3408988  0.25511706 0.9007547  0.9007547 ]
# Inference time on image: 0.60
# 4692
# 6820
# 4692
# annotated_count 2
# counts 1
# IOU Score: 0.6879765395894428
#
# 106 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_07-03-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_07-03-12_large.jpg
# [0.36550093 0.49073476 0.34130123 0.18341134 0.84350073 0.84350073]
# Inference time on image: 0.50
# 3850
# 4950
# 4165
# annotated_count 1
# counts 1
# IOU Score: 0.7312440645773979
#
# 107 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-24_17-39-58_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-24_17-39-58_large.jpg
# Inference time on image: 0.82
# 0
# 1
# 4690
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 108 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_18-01-08_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_18-01-08_large.jpg
# [0.5024785  0.73947024 0.7477921  0.36258873 0.60844207 0.60844207]
# Inference time on image: 0.57
# 7301
# 21120
# 7748
# annotated_count 1
# counts 1
# IOU Score: 0.33852645245050306
#
# 109 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_09-52-39_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_09-52-39_large.jpg
# [0.4043482  0.7218198  0.78479326 0.32956344 0.7254177  0.7254177 ]
# [0.89331853 0.8119086  0.20990168 0.3093667  0.6456146  0.6456146 ]
# Inference time on image: 0.64
# 5016
# 20160
# 5016
# annotated_count 1
# counts 2
# IOU Score: 0.2488095238095238
#
# 110 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-11_13-12-37_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-11_13-12-37_large.jpg
# Inference time on image: 0.49
# 0
# 1
# 3036
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 111 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_14-05-03_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_14-05-03_large.jpg
# Inference time on image: 0.49
# 0
# 1
# 7332
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 112 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_19-14-21_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_19-14-21_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 4408
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 113 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_15-44-39_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_15-44-39_large.jpg
# [0.6613942  0.4134328  0.5559291  0.30123332 0.7854922  0.7854922 ]
# Inference time on image: 0.54
# 12250
# 12994
# 12600
# annotated_count 1
# counts 1
# IOU Score: 0.918015587529976
#
# 114 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_07-40-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_07-40-12_large.jpg
# [0.47387907 0.7951526  0.87611747 0.35846525 0.9103797  0.9103797 ]
# Inference time on image: 0.54
# 0
# 24447
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 115 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-11_12-02-21_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-11_12-02-21_large.jpg
# [0.4985426  0.8293295  1.0157946  0.38002986 0.63628846 0.63628846]
# Inference time on image: 0.54
# 1652
# 29992
# 1652
# annotated_count 1
# counts 1
# IOU Score: 0.05508135502800747
#
# 116 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_08-27-11_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_08-27-11_large.jpg
# [0.49861002 0.802804   0.86939657 0.32744107 0.7808483  0.7808483 ]
# Inference time on image: 0.55
# 0
# 22041
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 117 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_08-16-21_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_08-16-21_large.jpg
# [0.19387266 0.2975778  0.34353688 0.24763751 0.82016283 0.82016283]
# Inference time on image: 0.52
# 6600
# 6600
# 8190
# annotated_count 1
# counts 1
# IOU Score: 0.8058608058608059
#
# 118 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_06-55-57_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_06-55-57_large.jpg
# [0.44215047 0.8026232  0.9795886  0.3653912  0.7031697  0.7031697 ]
# Inference time on image: 0.58
# 0
# 27632
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 119 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-21_11-15-20_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-21_11-15-20_large.jpg
# [0.3328927  0.8664006  0.470125   0.21538788 0.8725567  0.8725567 ]
# Inference time on image: 0.60
# 0
# 7852
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 120 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-05-27_12-46-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-05-27_12-46-12_large.jpg
# [0.50801855 0.732721   0.8138659  0.2992641  0.67988145 0.67988145]
# Inference time on image: 0.57
# 3150
# 18792
# 3150
# annotated_count 1
# counts 1
# IOU Score: 0.16762452107279693
#
# 121 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-23_11-58-24_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-23_11-58-24_large.jpg
# [0.36581215 0.75092226 0.535339   0.31181926 0.9322167  0.9322167 ]
# Inference time on image: 0.52
# 0
# 12900
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 122 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-21_16-39-29_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-21_16-39-29_large.jpg
# [0.45233828 0.9034368  0.3190367  0.1569404  0.7901149  0.7901149 ]
# Inference time on image: 0.55
# 0
# 3914
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 123 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_17-47-55_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_17-47-55_large.jpg
# Inference time on image: 0.61
# 0
# 1
# 4551
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 124 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_08-49-25_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_08-49-25_large.jpg
# [0.49523863 0.74983    0.97378075 0.34793693 0.8590798  0.8590798 ]
# Inference time on image: 0.55
# 7049
# 26208
# 7448
# annotated_count 2
# counts 1
# IOU Score: 0.26493028150486714
#
# 125 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_07-02-42_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_07-02-42_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 4292
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 126 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_18-39-50_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_18-39-50_large.jpg
# Inference time on image: 0.48
# 0
# 1
# 3708
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 127 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_07-54-08_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_07-54-08_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 4704
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 128 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_17-44-18_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_17-44-18_large.jpg
# [0.13219026 0.5687911  0.24134594 0.23853539 0.7953442  0.7953442 ]
# Inference time on image: 0.49
# 3198
# 4524
# 3567
# annotated_count 1
# counts 1
# IOU Score: 0.6535867565910485
#
# 129 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_09-47-25_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_09-47-25_large.jpg
# [0.3003988  0.559997   0.3412407  0.23044819 0.87740904 0.87740904]
# Inference time on image: 0.59
# 4815
# 6160
# 5265
# annotated_count 2
# counts 1
# IOU Score: 0.7284417549167927
#
# 130 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_10-39-43_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_10-39-43_large.jpg
# [0.2892575  0.66978955 0.20305854 0.2139036  0.67055124 0.67055124]
# [0.48246723 0.7532981  0.715076   0.351423   0.76001376 0.76001376]
# Inference time on image: 0.54
# 1885
# 3380
# 2581
# annotated_count 1
# counts 2
# IOU Score: 0.4624631992149166
#
# 131 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_17-54-37_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_17-54-37_large.jpg
# [0.6818186  0.82300335 0.37255555 0.2604376  0.8522297  0.8522297 ]
# Inference time on image: 0.53
# 6720
# 7560
# 7280
# annotated_count 1
# counts 1
# IOU Score: 0.8275862068965517
#
# 132 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_07-44-33_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_07-44-33_large.jpg
# Inference time on image: 0.60
# 0
# 1
# 5304
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 133 of 198
# ...
# Inference time on image: 0.64
# 4905
# 5341
# 6030
# annotated_count 1
# counts 1
# IOU Score: 0.7585833591091865
#
# 153 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_14-04-40_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_14-04-40_large.jpg
# Inference time on image: 0.79
# 0
# 1
# 4130
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 154 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_12-39-29_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_12-39-29_large.jpg
# [0.2236255  0.6288728  0.32188046 0.24031304 0.89491236 0.89491236]
# Inference time on image: 0.52
# 3640
# 6032
# 3920
# annotated_count 1
# counts 1
# IOU Score: 0.5766793409378961
#
# 155 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_13-58-53_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_13-58-53_large.jpg
# Inference time on image: 0.48
# 0
# 1
# 6063
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 156 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_14-27-26_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_14-27-26_large.jpg
# [0.14013897 0.8576367  0.277252   0.1951784  0.8566797  0.8566797 ]
# Inference time on image: 0.51
# 0
# 4183
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 157 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_09-30-06_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_09-30-06_large.jpg
# Inference time on image: 0.49
# 0
# 1
# 4060
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 158 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_10-37-24_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_10-37-24_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 3672
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 159 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_19-03-04_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_19-03-04_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 8442
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 160 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_17-55-06_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_17-55-06_large.jpg
# Inference time on image: 0.49
# 0
# 1
# 2145
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 161 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_16-17-07_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_16-17-07_large.jpg
# [0.28688312 0.600089   0.26101926 0.18387833 0.710315   0.710315  ]
# Inference time on image: 0.67
# 3108
# 3780
# 4144
# annotated_count 1
# counts 1
# IOU Score: 0.6453488372093024
#
# 162 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_13-27-15_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_13-27-15_large.jpg
# [0.25517625 0.6318337  0.31800354 0.2357736  0.8595393  0.8595393 ]
# Inference time on image: 0.50
# 3895
# 5814
# 4223
# annotated_count 2
# counts 1
# IOU Score: 0.6341582546401824
#
# 163 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-17_06-30-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-17_06-30-12_large.jpg
# [0.51823545 0.7966376  0.96638733 0.3018222  0.741714   0.741714  ]
# Inference time on image: 0.60
# 5640
# 22630
# 5640
# annotated_count 1
# counts 1
# IOU Score: 0.24922669023420238
#
# 164 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_10-43-56_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_10-43-56_large.jpg
# [0.14819685 0.86327386 0.27198187 0.22250833 0.8983368  0.8983368 ]
# Inference time on image: 0.51
# 0
# 4752
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 165 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_14-48-31_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_14-48-31_large.jpg
# Inference time on image: 0.49
# 0
# 1
# 7436
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 166 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-24_15-32-21_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-24_15-32-21_large.jpg
# Inference time on image: 0.65
# 0
# 1
# 7003
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 167 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_08-11-20_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_08-11-20_large.jpg
# [0.26708493 0.60883236 0.32818082 0.22491959 0.79968214 0.79968214]
# Inference time on image: 0.63
# 0
# 5724
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 168 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_16-27-12_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_16-27-12_large.jpg
# Inference time on image: 0.51
# 0
# 1
# 7506
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 169 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_06-26-49_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_06-26-49_large.jpg
# Inference time on image: 0.47
# 0
# 1
# 5175
# annotated_count 2
# counts 0
# IOU Score: 0.0
#
# 170 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-20_06-54-09_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-20_06-54-09_large.jpg
# Inference time on image: 0.65
# 0
# 1
# 4864
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 171 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_19-03-18_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_19-03-18_large.jpg
# Inference time on image: 0.48
# 0
# 1
# 3876
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 172 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_17-08-51_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_17-08-51_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 5226
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 173 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_10-53-11_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_10-53-11_large.jpg
# Inference time on image: 0.56
# 0
# 1
# 4360
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 174 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_15-13-45_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_15-13-45_large.jpg
# Inference time on image: 0.63
# 0
# 1
# 5031
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 175 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-11_12-25-28_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-11_12-25-28_large.jpg
# Inference time on image: 0.51
# 0
# 1
# 1633
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 176 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_07-37-15_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_07-37-15_large.jpg
# Inference time on image: 0.65
# 0
# 1
# 3135
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 177 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-19_13-43-13_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-19_13-43-13_large.jpg
# [0.26259705 0.5785023  0.42726046 0.23291296 0.91196877 0.91196877]
# Inference time on image: 0.50
# 5891
# 7672
# 6536
# annotated_count 1
# counts 1
# IOU Score: 0.7083082842371047
#
# 178 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_07-07-23_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_07-07-23_large.jpg
# [0.3720334  0.5293684  0.36363304 0.20196901 0.80939937 0.80939937]
# Inference time on image: 0.74
# 4797
# 5733
# 5330
# annotated_count 1
# counts 1
# IOU Score: 0.7655601659751037
#
# 179 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_18-56-51_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_18-56-51_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 5510
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 180 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_08-12-40_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_08-12-40_large.jpg
# [0.5553596  0.82495916 0.6256685  0.36493114 0.8898848  0.8898848 ]
# Inference time on image: 0.58
# 0
# 17688
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 181 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_10-39-32_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_10-39-32_large.jpg
# [0.42426512 0.60421395 0.37470797 0.20675245 0.8327766  0.8327766 ]
# Inference time on image: 0.56
# 5160
# 6000
# 5418
# annotated_count 1
# counts 1
# IOU Score: 0.8245445829338447
#
# 182 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-14_09-07-56_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-14_09-07-56_large.jpg
# [0.51861435 0.7262179  0.8284377  0.37265685 0.602458   0.602458  ]
# Inference time on image: 0.59
# 7889
# 23940
# 7889
# annotated_count 1
# counts 1
# IOU Score: 0.32953216374269007
#
# 183 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-11_08-51-53_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-11_08-51-53_large.jpg
# [0.49541557 0.8205218  0.9441157  0.28625742 0.8311749  0.8311749 ]
# Inference time on image: 0.54
# 2523
# 20907
# 2523
# annotated_count 1
# counts 1
# IOU Score: 0.12067728511981633
#
# 184 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_18-35-50_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_18-35-50_large.jpg
# [0.5035493  0.8037185  0.9080076  0.37865722 0.86796254 0.86796254]
# Inference time on image: 0.62
# 0
# 26481
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 185 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_13-45-28_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_13-45-28_large.jpg
# Inference time on image: 0.50
# 0
# 1
# 9699
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 186 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-10_12-26-16_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-10_12-26-16_large.jpg
# [0.48991734 0.835349   0.9835527  0.33245876 0.8290892  0.8290892 ]
# Inference time on image: 0.63
# 0
# 25200
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 187 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_08-11-43_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_08-11-43_large.jpg
# [0.4196357  0.8772991  0.3280015  0.18569002 0.81011873 0.81011873]
# Inference time on image: 0.54
# 0
# 4725
# 1
# annotated_count 0
# counts 1
# IOU Score: 0.0
#
# 188 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-05-27_07-37-24_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-05-27_07-37-24_large.jpg
# Inference time on image: 0.52
# 1
# 1
# 1
# annotated_count 0
# counts 0
# IOU Score: 1.0
#
# 189 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-16_11-02-20_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-16_11-02-20_large.jpg
# [0.123541   0.649239   0.22492406 0.22148198 0.8109135  0.8109135 ]
# Inference time on image: 0.50
# 2736
# 3888
# 2850
# annotated_count 1
# counts 1
# IOU Score: 0.6836581709145427
#
# 190 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_16-03-32_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_16-03-32_large.jpg
# Inference time on image: 0.48
# 0
# 1
# 1638
# annotated_count 8
# counts 0
# IOU Score: 0.0
#
# 191 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_17-17-33_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_17-17-33_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 11696
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 192 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-25_07-30-25_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-25_07-30-25_large.jpg
# Inference time on image: 0.46
# 0
# 1
# 3286
# annotated_count 1
# counts 0
# IOU Score: 0.0
#
# 193 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_15-48-05_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_15-48-05_large.jpg
# [0.49802014 0.7577587  1.0227942  0.34418792 0.88894135 0.88894135]
# Inference time on image: 0.63
# 5895
# 27224
# 6026
# annotated_count 1
# counts 1
# IOU Score: 0.21549990860902943
#
# 194 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_14-10-29_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_14-10-29_large.jpg
# [0.2746039  0.7951201  0.52055913 0.28263623 0.689084   0.689084  ]
# Inference time on image: 0.55
# 3444
# 11356
# 5412
# annotated_count 2
# counts 1
# IOU Score: 0.25848093665565897
#
# 195 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-15_18-20-35_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-15_18-20-35_large.jpg
# [0.44426087 0.7383797  0.8579419  0.36112207 0.691791   0.691791  ]
# Inference time on image: 0.63
# 5494
# 23925
# 5494
# annotated_count 1
# counts 1
# IOU Score: 0.2296342737722048
#
# 196 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-18_12-43-29_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-18_12-43-29_large.jpg
# [0.2090784  0.5777684  0.27084973 0.23302463 0.8722942  0.8722942 ]
# Inference time on image: 0.63
# 3010
# 4872
# 3010
# annotated_count 1
# counts 1
# IOU Score: 0.617816091954023
#
# 197 of 198
# a---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Annotations/2_2017-04-13_12-26-28_large.xml
#  herring_image---> ../data/Herring/Training/IRWA 2017 (Large+annotations)/Images/2_2017-04-13_12-26-28_large.jpg
# [0.37753522 0.6553458  0.2568322  0.20009485 0.6747363  0.6747363 ]
# Inference time on image: 0.56
# 2822
# 4067
# 3400
# annotated_count 1
# counts 1
# IOU Score: 0.607534983853606

# %%
def counts_ci(x):
    """Confidence interval for counts."""
    m = np.mean(x)
    me = 1.96 * np.sqrt(np.std(x) / len(x))
    return m - me, m + me


print("average IOU:", np.mean(iou_scores))
print("Total annotated counts:", sum(annotated_counts))
print(
    f"Annotated Counts breakdown: {Counter(annotated_counts)} ",
)
print(f"CI: {counts_ci(annotated_counts)}")
print()
print("Total predicted counts:", sum(predicted_counts))
print("Annotated Counts breakdown:", Counter(predicted_counts))
print(
    f"Ratio of predicted to expected: { sum(predicted_counts) / sum(annotated_counts):.3f}"
)
print(f"CI for predicted counts: {counts_ci(predicted_counts)}")
diff = [predicted_counts[i] - annotated_counts[i] for i in range(len(predicted_counts))]
print()
print(f"CI for predicted - annotated counts: {counts_ci(diff)}")
# Out:
# average IOU: 0.2536005399180805
# Total annotated counts: 188
# Annotated Counts breakdown: Counter({1: 138, 0: 40, 2: 15, 3: 4, 8: 1})
# CI: (0.8267242963911421, 1.072265602598757)
#
# Total predicted counts: 116
# Annotated Counts breakdown: Counter({1: 97, 0: 92, 2: 8, 3: 1})
# Ratio of predicted to expected: 0.617
# CI for predicted counts: (0.4784363124240802, 0.6932808592930915)
#
# CI for predicted - annotated counts: (-0.5025421802891104, -0.2247305469836169)
